# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer

def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation and special characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    # Stem words
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    
    # Join the words back into a single string
    preprocessed_text = ' '.join(words)
    
    return preprocessed_text
a1="List is collection of non homogenious data type it is mutable in nature"
a2=" "
a3=" "
cleaned_audio_text=preprocess_text(a1)


print(cleaned_audio_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[3], line 28
#      26 a2=" "
#      27 a3=" "
# ---> 28 cleaned_audio_text=preprocess_text(a1)
#      31 print(cleaned_audio_text)
#
# Cell In[3], line 11, in preprocess_text(text)
#       8 text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
#      10 # Tokenize the text
# ---> 11 words = word_tokenize(text)
#      13 # Remove stopwords
#      14 stop_words = set(stopwords.words('english'))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\user/nltk_data'
#     - 'c:\\Program Files\\Python313\\nltk_data'
#     - 'c:\\Program Files\\Python313\\share\\nltk_data'
#     - 'c:\\Program Files\\Python313\\lib\\nltk_data'
#     - 'C:\\Users\\user\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
import pandas as pd

ds = pd.read_csv("question_set - Copy.csv", encoding='latin1')
ds
# Out:
#     sr_no                                           question  \
# 0       1             What are the subsets /commands of SQL?
# 1       2  what are CRUD operations and what are their uses?
# 2       3  Difference between WHERE and HAVING clause in ...
# 3       4  Difference between the PRIMARY key and the UNI...
# 4       5  Difference between TRUNCATE, DELETE and DROP i...
# 5       6  Difference between CHAR and VARCHAR data types...
# 6       7  Difference between LEFT and RIGHT OUTER JOIN i...
# 7       8                         What is SELF JOIN in SQL?
# 8       9  Can you use a JOIN without specifying a join c...
# 9      10  What are aggregate functions in SQL, and what ...
# 10     11  What is the difference between the COUNT funct...
# 11     12  Explain the usage of the GROUP BY clause with ...
# 12     13                   How do you create a view in SQL?
# 13     14  What is database normalization, and why is it ...
# 14     15       Explain the ACID properties of transactions.
# 15     16  What is the purpose of the ORDER BY clause in ...
# 16     17  What is a database trigger, and what events ca...
# 17     18                            What are SQL subquries?
#
#                                                   ans  \
# 0   Data definition language (DDL): It defines the...
# 1   CREATE - To create databases, tables, insert t...
# 2   The WHERE clause is used to filter rows before...
# 3   The PRIMARY key constraint is used to uniquely...
# 4   TRUNCATE is used to delete all the rows from a...
# 5   CHAR and VARCHAR are both data types used to \...
# 6   Both are outer joins, in LEFT outer join, all ...
# 7   When we join two instances of tables it's call...
# 8   Yes, you can use a CROSS JOIN (Cartesian Join)...
# 9   Aggregate functions are SQL functions used to ...
# 10  COUNT function with DISTINCT counts only the d...
# 11  The GROUP BY clause is used to group rows base...
# 12  To create a view in SQL, you use the CREATE VI...
# 13  Database normalization is the process of organ...
# 14  ACID stands for Atomicity, Consistency, Isolat...
# 15  The ORDER BY clause within Window Functions de...
# 16  A database trigger is a special type of stored...
# 17  Subqueries, also known as nested queries or in...
#
#                                                 ans 1
# 0   Data definition language (DDL): It defines the...
# 1   CREATE - To create databases, tables, insert t...
# 2   The WHERE clause is used to filter rows before...
# 3   The PRIMARY key constraint is used to uniquely...
# 4   TRUNCATE is used to delete all the rows from a...
# 5   CHAR and VARCHAR are both data types used to \...
# 6   Both are outer joins, in LEFT outer join, all ...
# 7   When we join two instances of tables it's call...
# 8   Yes, you can use a CROSS JOIN (Cartesian Join)...
# 9   Aggregate functions are SQL functions used to ...
# 10  COUNT function with DISTINCT counts only the d...
# 11  The GROUP BY clause is used to group rows base...
# 12  To create a view in SQL, you use the CREATE VI...
# 13  Database normalization is the process of organ...
# 14  ACID stands for Atomicity, Consistency, Isolat...
# 15  The ORDER BY clause within Window Functions de...
# 16  A database trigger is a special type of stored...
# 17  Subqueries, also known as nested queries or in...

# %%
ds["ans1"]=ds["ans 1"].astype(str).apply(preprocess_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds["ans1"]=ds["ans 1"].astype(str).apply(preprocess_text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[3], line 11, in preprocess_text(text)
#       8 text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
#      10 # Tokenize the text
# ---> 11 words = word_tokenize(text)
#      13 # Remove stopwords
#      14 stop_words = set(stopwords.words('english'))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\user/nltk_data'
#     - 'c:\\Program Files\\Python313\\nltk_data'
#     - 'c:\\Program Files\\Python313\\share\\nltk_data'
#     - 'c:\\Program Files\\Python313\\lib\\nltk_data'
#     - 'C:\\Users\\user\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
new_ds=ds[['sr_no','question','ans','ans 1']]
new_ds['ans1']=new_ds['ans 1'].apply(lambda x:"".join(x))

# %%
import pickle
with open("preprocess_data_copy.pkl",'wb')as file:
    pickle.dump(new_ds,file)

# %%
import pickle
new_ds = pickle.load(open('preprocess_data_copy.pkl', 'rb'))
new_ds
# Out:
#     sr_no                                           question  \
# 0       1             What are the subsets /commands of SQL?
# 1       2  what are CRUD operations and what are their uses?
# 2       3  Difference between WHERE and HAVING clause in ...
# 3       4  Difference between the PRIMARY key and the UNI...
# 4       5  Difference between TRUNCATE, DELETE and DROP i...
# 5       6  Difference between CHAR and VARCHAR data types...
# 6       7  Difference between LEFT and RIGHT OUTER JOIN i...
# 7       8                         What is SELF JOIN in SQL?
# 8       9  Can you use a JOIN without specifying a join c...
# 9      10  What are aggregate functions in SQL, and what ...
# 10     11  What is the difference between the COUNT funct...
# 11     12  Explain the usage of the GROUP BY clause with ...
# 12     13                   How do you create a view in SQL?
# 13     14  What is database normalization, and why is it ...
# 14     15       Explain the ACID properties of transactions.
# 15     16  What is the purpose of the ORDER BY clause in ...
# 16     17  What is a database trigger, and what events ca...
# 17     18                            What are SQL subquries?
#
#                                                   ans  \
# 0   Data definition language (DDL): It defines the...
# 1   CREATE - To create databases, tables, insert t...
# 2   The WHERE clause is used to filter rows before...
# 3   The PRIMARY key constraint is used to uniquely...
# 4   TRUNCATE is used to delete all the rows from a...
# 5   CHAR and VARCHAR are both data types used to \...
# 6   Both are outer joins, in LEFT outer join, all ...
# 7   When we join two instances of tables it's call...
# 8   Yes, you can use a CROSS JOIN (Cartesian Join)...
# 9   Aggregate functions are SQL functions used to ...
# 10  COUNT function with DISTINCT counts only the d...
# 11  The GROUP BY clause is used to group rows base...
# 12  To create a view in SQL, you use the CREATE VI...
# 13  Database normalization is the process of organ...
# 14  ACID stands for Atomicity, Consistency, Isolat...
# 15  The ORDER BY clause within Window Functions de...
# 16  A database trigger is a special type of stored...
# 17  Subqueries, also known as nested queries or in...
#
#                                                 ans 1  \
# 0   Data definition language (DDL): It defines the...
# 1   CREATE - To create databases, tables, insert t...
# 2   The WHERE clause is used to filter rows before...
# 3   The PRIMARY key constraint is used to uniquely...
# 4   TRUNCATE is used to delete all the rows from a...
# 5   CHAR and VARCHAR are both data types used to \...
# 6   Both are outer joins, in LEFT outer join, all ...
# 7   When we join two instances of tables it's call...
# 8   Yes, you can use a CROSS JOIN (Cartesian Join)...
# 9   Aggregate functions are SQL functions used to ...
# 10  COUNT function with DISTINCT counts only the d...
# 11  The GROUP BY clause is used to group rows base...
# 12  To create a view in SQL, you use the CREATE VI...
# 13  Database normalization is the process of organ...
# 14  ACID stands for Atomicity, Consistency, Isolat...
# 15  The ORDER BY clause within Window Functions de...
# 16  A database trigger is a special type of stored...
# 17  Subqueries, also known as nested queries or in...
#
#                                                  ans1
# 0   Data definition language (DDL): It defines the...
# 1   CREATE - To create databases, tables, insert t...
# 2   The WHERE clause is used to filter rows before...
# 3   The PRIMARY key constraint is used to uniquely...
# 4   TRUNCATE is used to delete all the rows from a...
# 5   CHAR and VARCHAR are both data types used to \...
# 6   Both are outer joins, in LEFT outer join, all ...
# 7   When we join two instances of tables it's call...
# 8   Yes, you can use a CROSS JOIN (Cartesian Join)...
# 9   Aggregate functions are SQL functions used to ...
# 10  COUNT function with DISTINCT counts only the d...
# 11  The GROUP BY clause is used to group rows base...
# 12  To create a view in SQL, you use the CREATE VI...
# 13  Database normalization is the process of organ...
# 14  ACID stands for Atomicity, Consistency, Isolat...
# 15  The ORDER BY clause within Window Functions de...
# 16  A database trigger is a special type of stored...
# 17  Subqueries, also known as nested queries or in...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_ds['ans']=new_ds['ans'].apply(stem)

# %%
new_ds['ans']=new_ds['ans'].apply(lambda x:x.lower())

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Function to get the top 1000 repeated words from a text
def get_top_words(text, n=30):
    # Tokenize the text into words
    words = text.split()
    # Count the frequency of each word
    word_freq = {}
    for word in words:
        word_freq[word] = word_freq.get(word, 0) + 1
    # Sort words by frequency and select the top n
    top_words = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)[:n]
    return [word[0] for word in top_words]

# Get the top 1000 repeated words from your resume
top_ans_word = get_top_words(cleaned_audio_text)

# Get the top 1000 repeated words from your dataset (assuming 'new_ds' is your dataset)
all_ans = new_ds['ans'].tolist()
top_dataset_words = get_top_words(' '.join(all_ans))

print(top_dataset_words,"\n\n")
print(top_ans_word)

# Combine the top words from resume and dataset
top_words = list(set(top_ans_word + top_dataset_words))

# Create a TF-IDF vectorizer with the top words
tfidf_vectorizer = TfidfVectorizer(vocabulary=top_words)

# Calculate TF-IDF vectors for your resume and each company description
tfidf_matrix = tfidf_vectorizer.fit_transform([cleaned_audio_text] + all_ans)

# Calculate cosine similarities
cosine_similarities = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1:]).flatten()

# Add similarity scores to the DataFrame
new_ds['Similarity Score'] = cosine_similarities*100

# Rank the job descriptions based on similarity scores
new_ds = new_ds.sort_values(by='Similarity Score', ascending=False)

# Filter job descriptions with a similarity score threshold
threshold = 0.1  # Adjust as needed
filtered_df = new_ds[new_ds['Similarity Score'] >= threshold]

# Sort the DataFrame by Similarity Score in descending order
filtered_df = filtered_df.sort_values(by='Similarity Score', ascending=False)

# Select the top 3 companies with the highest similarity scores
top_5_companies = filtered_df.nlargest(1, 'Similarity Score')

# Assign ratings to your resume for the top 3 companies
top_5_companies['Ans_Rating'] = top_5_companies['Similarity Score']  # Example rating scale

# Display the top 3 companies
print(top_5_companies[['ans','Ans_Rating']])
# Out:
# ['the', 'to', 'is', 'a', 'use', 'in', 'and', 'of', 'data', 'tabl', 'row', 'are', 'it', 'or', 'that', 'group', 'on', 'for', 'store', 'from', 'aggreg', 'specifi', 'function', 'ensur', 'be', 'databas', 'as', 'defin', 'database.', 'transact']
#
#
# ['list', 'collect', 'non', 'homogeni', 'data', 'type', 'mutabl', 'natur']
#                                                  ans  Ans_Rating
# 5  char and varchar are both data type use to sto...   16.146845
